# %%
import cv2
import openpose as op
import numpy as np

# %%
op.Video_processing('pose/models/Turn_Right/test.mp4','pose/models/Turn_Right/test.npy')
# Out:
# Start processing
# ............................................................
# Processing complete  1
# ............................................................
# Processing complete  2
# ............................................................
# Processing complete  3
# ............................................................
# Processing complete  4
# ............................................................
# Processing complete  5
# ............................................................
# Processing complete  6
# ............................................................
# Processing complete  7
# ............................................................
# Processing complete  8
# ............................................................
# Processing complete  9
# ............................................................
# Processing complete  10
# ............................................................
# Processing complete  11
# ...

# %%
ary = np.load('pose/models/Turn_Right/test.npy')

# %%
ary.shape
# Out:
# (77, 25, 2)

# %%
for i in range(77):
    map = op.getkeyary(ary[i,:,:])
    cv2.imshow("map",map )
    #  add below code
    cv2.waitKey(50)
cv2.destroyAllWindows()
